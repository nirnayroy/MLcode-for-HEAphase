# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

class Flatten(torch.nn.Module):
    def forward(self, input):
        return input.view(input.size(0), -1)
    
num_of_feature = 11
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-739e7cf081e8> in <module>
# ----> 1 import torch
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#       4
#       5 class Flatten(torch.nn.Module):
#
# ModuleNotFoundError: No module named 'torch'

# %%
# model = torch.nn.Sequential(
#     torch.nn.Linear(13, 64),
#     torch.nn.LeakyReLU(),
#     torch.nn.Linear(64, 32),
#     torch.nn.LeakyReLU(),
#     torch.nn.Linear(32, 2),
# )

model = torch.nn.Sequential(
    torch.nn.Conv1d(1, 64, 3, 1), #11
    torch.nn.Tanh(),
    torch.nn.Conv1d(64, 128, 3, 1), #9
    torch.nn.Tanh(),
    Flatten(),
    torch.nn.Linear(128*(num_of_feature-4), 2)
#     torch.nn.Linear(128, 2)
#     torch.nn.Linear(576, 2)
    )

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
def train(batch, epoch, dataset):
    x_train = np.load('data/x_train_11.npy') #420
    x_val = np.load('data/x_val_11.npy')     #91
    x_test = np.load('data/x_test_11.npy')   #90
    y_train = np.load('data/y_train_' + dataset + '_11.npy')
    y_val = np.load('data/y_val_' + dataset + '_11.npy')
    y_test = np.load('data/y_test_' + dataset + '_11.npy')
    x_train = np.expand_dims(x_train, axis=1)
    x_val = np.expand_dims(x_val, axis=1)
    x_test = np.expand_dims(x_test, axis=1)
    data_pred = np.load('data/for_pred_11.npy')
    data_pred = np.expand_dims(data_pred, axis=1)
    indicies = np.arange(x_train.shape[0])
    epoch_loss = []
    epoch_accuracy = []
    val_accuracy = []
    test_accuracy = []
    IM_accuracy = []
    data_pred_labels = []
    for e in range(epoch):
        losses = []
        accuracies = []
        for i in range(0, int(np.ceil(x_train.shape[0]/batch))):
            start_idx = (i * batch) % x_train.shape[0]
            idx = indicies[start_idx: start_idx + batch]
            x_in = torch.from_numpy(x_train[idx]).type(torch.float32)
            y_in = torch.from_numpy(y_train[idx]).type(torch.long)
            y_score = model(x_in)
            predict = torch.argmax(y_score, 1)
            difference = predict == y_in
            accuracy = torch.mean(difference.type(torch.float32))
            loss = torch.nn.CrossEntropyLoss()
            loss = loss(y_score, y_in)
#             print('loss: ', loss.item(),' accuracy: ', accuracy.item())
            losses.append(loss.item())
            accuracies.append(accuracy.item())
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        print('epoch ', e, ' with loss: %.4f' %np.mean(losses), ' and accuracy: %.4f' %np.mean(accuracies))
        epoch_loss.append(np.mean(losses))
        epoch_accuracy.append(np.mean(accuracies))
        
        x_val_in = torch.from_numpy(x_val).type(torch.float32)
        y_val_in = torch.from_numpy(y_val).type(torch.long)
        y_val_score = model(x_val_in)
        val_predict = torch.argmax(y_val_score, 1) == y_val_in
        val_acc = torch.mean(val_predict.type(torch.float32))
        val_accuracy.append(val_acc.item())
        
        x_test_in = torch.from_numpy(x_test).type(torch.float32)
        y_test_in = torch.from_numpy(y_test).type(torch.long)
        y_test_score = model(x_test_in)
        test_predict = torch.argmax(y_test_score, 1) == y_test_in
        test_acc = torch.mean(test_predict.type(torch.float32))
        test_accuracy.append(test_acc.item())
        
        data_pred_in = torch.from_numpy(data_pred).type(torch.float32)
        data_pred_score = model(data_pred_in)
        data_pred_label = torch.argmax(data_pred_score, 1)
        data_pred_labels.append(data_pred_label)
        
        print('epoch ', e, ' with val_accuracy: %.4f' %val_acc.item(), ' and test_accuracy: %.4f' %test_acc.item())
    
with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  36  with loss: 0.0884  and accuracy: 0.9690
# epoch  36  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  37  with loss: 0.0869  and accuracy: 0.9690
# epoch  37  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  38  with loss: 0.0854  and accuracy: 0.9714
# epoch  38  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  39  with loss: 0.0839  and accuracy: 0.9714
# epoch  39  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  40  with loss: 0.0825  and accuracy: 0.9714
# epoch  40  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  41  with loss: 0.0810  and accuracy: 0.9714
# epoch  41  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  42  with loss: 0.0797  and accuracy: 0.9714
# epoch  42  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  43  with loss: 0.0783  and accuracy: 0.9738
# epoch  43  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  44  with loss: 0.0770  and accuracy: 0.9762
# epoch  44  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  45  with loss: 0.0757  and accuracy: 0.9786
# epoch  45  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  46  with loss: 0.0744  and accuracy: 0.9786
# epoch  46  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  47  with loss: 0.0732  and accuracy: 0.9786
# epoch  47  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  48  with loss: 0.0719  and accuracy: 0.9786
# epoch  48  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  49  with loss: 0.0707  and accuracy: 0.9810
# epoch  49  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  50  with loss: 0.0695  and accuracy: 0.9810
# epoch  50  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  51  with loss: 0.0684  and accuracy: 0.9810
# epoch  51  with val_accuracy: 0.9890  and test_accuracy: 0.9667
# epoch  52  with loss: 0.0672  and accuracy: 0.9810
# epoch  52  with val_accuracy: 0.9890  and test_accuracy: 0.9667
# epoch  53  with loss: 0.0661  and accuracy: 0.9810
# epoch  53  with val_accuracy: 0.9890  and test_accuracy: 0.9667
# epoch  54  with loss: 0.0650  and accuracy: 0.9786
# epoch  54  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  55  with loss: 0.0639  and accuracy: 0.9786
# epoch  55  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  56  with loss: 0.0628  and accuracy: 0.9786
# epoch  56  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  57  with loss: 0.0617  and accuracy: 0.9786
# epoch  57  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  58  with loss: 0.0607  and accuracy: 0.9786
# epoch  58  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  59  with loss: 0.0596  and accuracy: 0.9786
# epoch  59  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  60  with loss: 0.0585  and accuracy: 0.9786
# epoch  60  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  61  with loss: 0.0575  and accuracy: 0.9786
# epoch  61  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  62  with loss: 0.0565  and accuracy: 0.9786
# epoch  62  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  63  with loss: 0.0554  and accuracy: 0.9786
# epoch  63  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  64  with loss: 0.0544  and accuracy: 0.9786
# epoch  64  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  65  with loss: 0.0534  and accuracy: 0.9786
# epoch  65  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  66  with loss: 0.0525  and accuracy: 0.9786
# epoch  66  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  67  with loss: 0.0515  and accuracy: 0.9786
# epoch  67  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  68  with loss: 0.0506  and accuracy: 0.9786
# epoch  68  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  69  with loss: 0.0497  and accuracy: 0.9786
# epoch  69  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  70  with loss: 0.0488  and accuracy: 0.9786
# epoch  70  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  71  with loss: 0.0479  and accuracy: 0.9786
# epoch  71  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# epoch  72  with loss: 0.0471  and accuracy: 0.9786
# epoch  72  with val_accuracy: 0.9890  and test_accuracy: 0.9556
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e6b9fff0549b> in <module>
# ----> 1 data_pred_labels = train(20, 200, 'SS')
#
# <ipython-input-3-0c3c66afe68f> in train(batch, epoch, dataset)
#      31             x_in = torch.from_numpy(x_train[idx]).type(torch.float32)
#      32             y_in = torch.from_numpy(y_train[idx]).type(torch.long)
# ---> 33             y_score = model(x_in)
#      34             predict = torch.argmax(y_score, 1)
#      35             difference = predict == y_in
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     185     def forward(self, input):
#     186         return F.conv1d(input, self.weight, self.bias, self.stride,
# --> 187                         self.padding, self.dilation, self.groups)
#     188
#     189
#
# KeyboardInterrupt:

# %%
print(data_pred_labels[70])
